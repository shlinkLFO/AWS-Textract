# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv(r'C:\Users\mason\td\VIX-Calls-01-22.csv')

# %%
df.head()
# Out:
#   'Strike 'Symbol   'Bid   'Ask 'Price 'TPrice 'Volume      'OI 'NS    'IVol  \
# 0     '14    'VIX  '4.55  '4.60  '4.80   '5.31    '269    '5099  'S  '1.3804
# 1   '14.5    'VIX  '4.05  '4.15  '3.97   '4.85      '6     '677  'S  '1.3635
# 2     '15    'VIX  '3.55  '3.65  '3.60   '4.41    '195   '21640  'S  '1.3511
# 3   '15.5    'VIX  '3.10  '3.15  '4.23   '3.98      '7     '819  'S  '1.3420
# 4     '16    'VIX  '2.65  '2.70  '2.60   '3.58   '1163  '100917  'S  '1.3351
#
#     'Delta    'Theta   'Gamma    'Vega     'Rho 'Strike.1  Unnamed: 16
# 0  '0.9410  '-0.0272  '0.0283  '0.0035  '0.0031       '14          NaN
# 1  '0.9216  '-0.0335  '0.0356  '0.0044  '0.0032     '14.5          NaN
# 2  '0.8975  '-0.0405  '0.0439  '0.0054  '0.0032       '15          NaN
# 3  '0.8684  '-0.0480  '0.0528  '0.0064  '0.0031     '15.5          NaN
# 4  '0.8345  '-0.0556  '0.0618  '0.0075  '0.0031       '16          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   'Strike      21 non-null     object
#  1   'Symbol      21 non-null     object
#  2   'Bid         21 non-null     object
#  3   'Ask         21 non-null     object
#  4   'Price       21 non-null     object
#  5   'TPrice      21 non-null     object
#  6   'Volume      21 non-null     object
#  7   'OI          21 non-null     object
#  8   'NS          21 non-null     object
#  9   'IVol        21 non-null     object
#  10  'Delta       21 non-null     object
#  11  'Theta       21 non-null     object
#  12  'Gamma       21 non-null     object
#  13  'Vega        21 non-null     object
#  14  'Rho         21 non-null     object
#  15  'Strike.1    21 non-null     object
#  16  Unnamed: 16  0 non-null      float64
# dtypes: float64(1), object(16)
# memory usage: 2.9+ KB

# %%
df.columns = [col.replace("'", "") for col in df.columns]

df = df.applymap(lambda x: str(x).replace("'", ""))

for col in df.columns:
    try:
        df[col] = pd.to_numeric(df[col])
    except ValueError:
        pass
# Out:
# C:\Users\mason\AppData\Local\Temp\ipykernel_9588\3051412960.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: str(x).replace("'", ""))

# %%
df.head()
# Out:
#    Strike Symbol   Bid   Ask  Price  TPrice  Volume      OI NS    IVol  \
# 0    14.0    VIX  4.55  4.60   4.80    5.31     269    5099  S  1.3804
# 1    14.5    VIX  4.05  4.15   3.97    4.85       6     677  S  1.3635
# 2    15.0    VIX  3.55  3.65   3.60    4.41     195   21640  S  1.3511
# 3    15.5    VIX  3.10  3.15   4.23    3.98       7     819  S  1.3420
# 4    16.0    VIX  2.65  2.70   2.60    3.58    1163  100917  S  1.3351
#
#     Delta   Theta   Gamma    Vega     Rho  Strike.1 Unnamed: 16
# 0  0.9410 -0.0272  0.0283  0.0035  0.0031      14.0         nan
# 1  0.9216 -0.0335  0.0356  0.0044  0.0032      14.5         nan
# 2  0.8975 -0.0405  0.0439  0.0054  0.0032      15.0         nan
# 3  0.8684 -0.0480  0.0528  0.0064  0.0031      15.5         nan
# 4  0.8345 -0.0556  0.0618  0.0075  0.0031      16.0         nan

# %%
print(df)
# Out:
#     Strike Symbol   Bid   Ask  Price  TPrice  Volume      OI NS    IVol  \
# 0     14.0    VIX  4.55  4.60   4.80    5.31     269    5099  S  1.3804
# 1     14.5    VIX  4.05  4.15   3.97    4.85       6     677  S  1.3635
# 2     15.0    VIX  3.55  3.65   3.60    4.41     195   21640  S  1.3511
# 3     15.5    VIX  3.10  3.15   4.23    3.98       7     819  S  1.3420
# 4     16.0    VIX  2.65  2.70   2.60    3.58    1163  100917  S  1.3351
# 5     16.5    VIX  2.27  2.31   2.35    3.20     194   34595  S  1.3298
# 6     17.0    VIX  1.95  2.00   1.97    2.84   10816  136518  S  1.3258
# 7     17.5    VIX  1.70  1.75   1.71    2.51      35   37628  S  0.3506
# 8     18.0    VIX  1.50  1.54   1.49    2.20   10238  171780  S  0.6748
# 9     18.5    VIX  1.33  1.37   1.34    1.92    2410   21261  S  0.8099
# 10    19.0    VIX  1.19  1.24   1.19    1.67    4755   99119  S  0.9348
# 11    19.5    VIX  1.07  1.12   1.08    1.44    2009   20298  S  1.0149
# ...
